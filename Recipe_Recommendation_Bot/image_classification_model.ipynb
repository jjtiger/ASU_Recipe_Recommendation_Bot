# %% [markdown]
# # Introuction
# This notebook is divided into two parts:
# - Part 1: Data preprocessing and model training
# - Part 2: Model evaluation and prediction on test data
#
# If you do not want to start a new training session i would recommend reviewing part one but only loading the libraries and heading to part two to plotting and evaluating the model metrics.
#
# within the github repo you can find the data and the model save file along with the history of training.

# %% [markdown]
# # Part 1 : Data preprocessing and model training

# %% [markdown]
# ## Importing the libraries needed for the project

# %%
# Tensorflow and Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dropout
from keras_preprocessing import image
import tensorflow.keras.layers as layers


# Sklearn model performance utils
from sklearn.metrics import roc_curve, plot_roc_curve, auc 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import jaccard_score

# Misc libraries for other tasks 
import os
from pathlib import Path
import numpy as np
import pandas as pd
import pickle as pkl
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
# used to prepare the image directory and split into train , validate , test for keras
# import splitfolders

# %% [markdown]
# ### loading the images into a tensor flow dataframe object

# %%
# Split with a ratio only done once per project directory 
# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.

#image_folder = Path('/food_data/images')

#output_folder = Path('/food_data/output')

#splitfolders.ratio(image_folder, output=output_folder,
    #seed=1337, ratio=(.8, .1, .1), group_prefix=None, move=False) # default values

# %% [markdown]
# ## Model 1 with 148 Classes

# %% [markdown]
# ### Creating the traning and test dataframes using keras

# %%
# creatnig the training, testing and validation 
train_df_148 = image_dataset_from_directory(
    directory = '../Jay-branch/food_data/output/train',
    labels = 'inferred',
    label_mode = 'categorical',
    seed = 5,
    color_mode="rgb",
    shuffle = True ,
    batch_size = 32 ,
    image_size = (100,100),
    
    
    )

test_df_148 = image_dataset_from_directory(
    directory = '../Jay-branch/food_data/output/test',
    labels = 'inferred',
    label_mode = 'categorical',
    seed = 5,
    color_mode="rgb",
    shuffle = True ,
    batch_size = 32 ,
    image_size = (100,100)
    )

val_df_148 = image_dataset_from_directory(
    directory = '../Jay-branch/food_data/output/val',
    labels = 'inferred',
    label_mode = 'categorical',
    seed = 5,
    color_mode="rgb",
    shuffle = True ,
    batch_size = 32 ,
    image_size = (100,100)
    )
# Out:
# Found 91237 files belonging to 148 classes.
# Found 11415 files belonging to 148 classes.
# Found 11358 files belonging to 148 classes.

# %%
labels_148 = test_df_148.class_names
labels_148_df = pd.DataFrame(labels_148)
labels_148_df.columns =['ingredient']
labels_148_df
labels_148_df.to_csv('labels_148.csv')

# %% [markdown]
# ### Visualizing the data

# %%
# plotting a sample of the images
plt.figure(figsize=(10,10))

for image , label in train_df_148.take(1):
    for i in range(6):
        ax = plt.subplot(3 ,3, i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.axis('off')

# %% [markdown]
# ### Define the model architecture and fitting the model

# %%
# The model will be a multi layer Conv2D and Maxpooling with Dropouts to help prevent overfitting , towrds the end 1 Dens layer will be there before our final output
model_148 = Sequential()
#layer 1,2,3 sequence 
model_148.add(Conv2D(filters= 32, kernel_size=(3,3),activation='relu',input_shape = (100, 100, 3)))
model_148.add(MaxPooling2D((2,2)))
model_148.add(Dropout(0.2))
#layer 4,5,6 sequence 
model_148.add(Conv2D(filters= 64, kernel_size=(3,3),activation='relu'))
model_148.add(MaxPooling2D((2,2)))
model_148.add(Dropout(0.2))

#Dense Network
model_148.add(Flatten())
model_148.add(Dense(1500,activation='relu'))
model_148.add(Dense(500,activation='relu'))
model_148.add(Dense(250,activation='relu'))
#output layer with 148 classifications 
model_148.add(Dense(148,activation='softmax'))

# compile the model_148
# using the adam optimizer and categorical crossentropy for loss as we are using one-hot encoding style catagories
model_148.compile(optimizer='adam' , 
              loss='categorical_crossentropy' ,
              metrics=[
                    'accuracy',
                    tf.keras.metrics.TruePositives(name="tp"),
                    tf.keras.metrics.TrueNegatives(name="tn"),
                    tf.keras.metrics.FalsePositives(name="fp"),
                    tf.keras.metrics.FalseNegatives(name="fn"),
                    tf.keras.metrics.Precision(name="precision"),
                    tf.keras.metrics.Recall(name="recall"),
                    tf.keras.metrics.AUC(name="auc"),
                    ]
            )


# printing out a summary of the model_148
# 
model_148.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 32)       0
#  )
#
#  dropout (Dropout)           (None, 49, 49, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 23, 23, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 23, 23, 64)        0
#
#  flatten (Flatten)           (None, 33856)             0
#
#  dense (Dense)               (None, 1500)              50785500
#
#  dense_1 (Dense)             (None, 500)               750500
#
#  dense_2 (Dense)             (None, 250)               125250
#
#  dense_3 (Dense)             (None, 148)               37148
#
# =================================================================
# Total params: 51,717,790
# Trainable params: 51,717,790
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting the model with our traning dataset
history_148 = model_148.fit(train_df_148 , epochs=100 , batch_size=5 , validation_data=val_df , verbose=1)
with open('model_148_history' , 'wb') as file:
 pkl.dump(history_148.history, file)
# Out:
# Epoch 1/100
# 2850/2850 [==============================] - 11979s 4s/step - loss: 9.3801 - accuracy: 0.0125 - tp: 1.0000 - tn: 13404826.0000 - fp: 398.0000 - fn: 91191.0000 - precision: 0.0025 - recall: 1.0966e-05 - auc: 0.6140 - val_loss: 4.8036 - val_accuracy: 0.0132 - val_tp: 0.0000e+00 - val_tn: 1672713.0000 - val_fp: 0.0000e+00 - val_fn: 11379.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6183
# Epoch 2/100
# 2850/2850 [==============================] - 203s 71ms/step - loss: 4.8072 - accuracy: 0.0131 - tp: 0.0000e+00 - tn: 13405221.0000 - fp: 3.0000 - fn: 91192.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.6195 - val_loss: 4.8006 - val_accuracy: 0.0135 - val_tp: 0.0000e+00 - val_tn: 1672713.0000 - val_fp: 0.0000e+00 - val_fn: 11379.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6202
# Epoch 3/100
# 2850/2850 [==============================] - 228s 80ms/step - loss: 4.8030 - accuracy: 0.0130 - tp: 2.0000 - tn: 13405220.0000 - fp: 4.0000 - fn: 91190.0000 - precision: 0.3333 - recall: 2.1932e-05 - auc: 0.6240 - val_loss: 4.7986 - val_accuracy: 0.0129 - val_tp: 0.0000e+00 - val_tn: 1672713.0000 - val_fp: 0.0000e+00 - val_fn: 11379.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6218
# Epoch 4/100
# 2850/2850 [==============================] - 271s 95ms/step - loss: 4.8058 - accuracy: 0.0131 - tp: 0.0000e+00 - tn: 13405217.0000 - fp: 7.0000 - fn: 91192.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.
# Epoch 12/100
# 2850/2850 [==============================] - 301s 105ms/step - loss: 4.3742 - accuracy: 0.0362 - tp: 210.0000 - tn: 13405040.0000 - fp: 184.0000 - fn: 90982.0000 - precision: 0.5330 - recall: 0.0023 - auc: 0.7748 - val_loss: 4.6389 - val_accuracy: 0.0267 - val_tp: 6.0000 - val_tn: 1672699.0000 - val_fp: 14.0000 - val_fn: 11373.0000 - val_precision: 0.3000 - val_recall: 5.2729e-04 - val_auc: 0.7154
# Epoch 13/100
# 2850/2850 [==============================] - 310s 109ms/step - loss: 4.2966 - accuracy: 0.0417 - tp: 257.0000 - tn: 13404997.0000 - fp: 227.0000 - fn: 90935.0000 - precision: 0.5310 - recall: 0.0028 - auc: 0.7919 - val_loss: 4.7082 - val_accuracy: 0.0267 - val_tp: 6.0000 - val_tn: 1672695.0000 - val_fp: 18.0000 - val_fn: 11373.0000 - val_precision: 0.2500 - val_recall: 5.2729e-04 - val_auc: 0.7135
# Epoch 14/100
# 2850/2850 [==============================] - 307s 108ms/step - loss: 4.1731 - accuracy: 0.0479 - tp: 385.0000 - tn: 13404936.0000 - fp: 288.0000 - fn: 90807.0000 - precision: 0.5721 - recall: 0.0042 - auc: 0.8168 - val_loss: 4.7838 - val_accuracy: 0.0279 - val_tp: 13.0000 - val_tn: 1672670.0000 - val_fp: 43.0000 - val_fn: 11366.0000 - val_precision: 0.2321 - val_recall: 0.0011 - val_auc: 0.7093
# Epoch 15/100
# 2850/2850 [==============================] - 284s 99ms/step - loss: 4.0727 - accuracy: 0.0554 - tp: 445.0000 - tn: 13404929.0000 - fp: 295.0000 - fn: 90747.0000 - precision: 0.6014 - recall: 0.0049 - auc: 0.8329 - val_loss: 4.8972 - val_accuracy: 0.0249 - val_tp: 11.0000 - val_tn: 1672672.0000 - val_fp: 41.0000 - val_fn: 11368.0000 - val_precision: 0.2115 - val_recall: 9.6669e-04 - val_auc: 0.7094
# Epoch 16/100
# 2850/2850 [==============================] - 295s 103ms/step - loss: 3.9776 - accuracy: 0.0608 - tp: 520.0000 - tn: 13404857.0000 - fp: 367.0000 - fn: 90672.0000 - precision: 0.5862 - recall: 0.0057 - auc: 0.8465 - val_loss: 4.9891 - val_accuracy: 0.0279 - val_tp: 12.0000 - val_tn: 1672669.0000 - val_fp: 44.0000 - val_fn: 11367.0000 - val_precision: 0.2143 - val_recall: 0.0011 - val_auc: 0.7051
# Epoch 17/100
# 2850/2850 [==============================] - 309s 108ms/step - loss: 3.8825 - accuracy: 0.0685 - tp: 606.0000 - tn: 13404806.0000 - fp: 418.0000 - fn: 90586.0000 - precision: 0.5918 - recall: 0.0066 - auc: 0.8603 - val_loss: 5.0744 - val_accuracy: 0.0265 - val_tp: 15.0000 - val_tn: 1672685.0000 - val_fp: 28.0000 - val_fn: 11364.0000 - val_precision: 0.3488 - val_recall: 0.0013 - val_auc: 0.7011
# Epoch 18/100
# 2850/2850 [==============================] - 271s 95ms/step - loss: 3.7665 - accuracy: 0.0768 - tp: 752.0000 - tn: 13404717.0000 - fp: 507.0000 - fn: 90440.0000 - precision: 0.5973 - recall: 0.0082 - auc: 0.8728 - val_loss: 5.1626 - val_accuracy: 0.0267 - val_tp: 16.0000 - val_tn: 1672660.0000 - val_fp: 53.0000 - val_fn: 11363.0000 - val_precision: 0.2319 - val_recall: 0.0014 - val_auc: 0.6976
# Epoch 19/100
# 2850/2850 [==============================] - 188s 66ms/step - loss: 3.7054 - accuracy: 0.0824 - tp: 899.0000 - tn: 13404660.0000 - fp: 564.0000 - fn: 90293.0000 - precision: 0.6145 - recall: 0.0099 - auc: 0.8791 - val_loss: 5.4615 - val_accuracy: 0.0248 - val_tp: 25.0000 - val_tn: 1672629.0000 - val_fp: 84.0000 - val_fn: 11354.0000 - val_precision: 0.2294 - val_recall: 0.0022 - val_auc: 0.6911
# Epoch 20/100
# 2850/2850 [==============================] - 192s 67ms/step - loss: 3.5983 - accuracy: 0.0921 - tp: 1115.0000 - tn: 13404564.0000 - fp: 660.0000 - fn: 90077.0000 - precision: 0.6282 - recall: 0.0122 - auc: 0.8900 - val_loss: 5.4508 - val_accuracy: 0.0275 - val_tp: 16.0000 - val_tn: 1672646.0000 - val_fp: 67.0000 - val_fn: 11363.0000 - val_precision: 0.1928 - val_recall: 0.0014 - val_auc: 0.6898
# Epoch 21/100
# 2850/2850 [==============================] - 211s 74ms/step - loss: 3.5444 - accuracy: 0.0992 - tp: 1209.0000 - tn: 13404438.0000 - fp: 786.0000 - fn: 89983.0000 - precision: 0.6060 - recall: 0.0133 - auc: 0.8951 - val_loss: 5.4303 - val_accuracy: 0.0232 - val_tp: 8.0000 - val_tn: 1672679.0000 - val_fp: 34.0000 - val_fn: 11371.0000 - val_precision: 0.1905 - val_recall: 7.0305e-04 - val_auc: 0.6882
# Epoch 22/100
# 2850/2850 [==============================] - 236s 83ms/step - loss: 3.4778 - accuracy: 0.1051 - tp: 1367.0000 - tn: 13404383.0000 - fp: 841.0000 - fn: 89825.0000 - precision: 0.6191 - recall: 0.0150 - auc: 0.9012 - val_loss: 5.5810 - val_accuracy: 0.0252 - val_tp: 20.0000 - val_tn: 1672656.0000 - val_fp: 57.0000 - val_fn: 11359.0000 - val_precision: 0.2597 - val_recall: 0.0018 - val_auc: 0.6878
# Epoch 23/100
# 2850/2850 [==============================] - 222s 78ms/step - loss: 3.4313 - accuracy: 0.1109 - tp: 1493.0000 - tn: 13404311.0000 - fp: 913.0000 - fn: 89699.0000 - precision: 0.6205 - recall: 0.0164 - auc: 0.9037 - val_loss: 5.7575 - val_accuracy: 0.0246 - val_tp: 19.0000 - val_tn: 1672634.0000 - val_fp: 79.0000 - val_fn: 11360.0000 - val_precision: 0.1939 - val_recall: 0.0017 - val_auc: 0.6857
# Epoch 24/100
# 2850/2850 [==============================] - 272s 95ms/step - loss: 3.3333 - accuracy: 0.1207 - tp: 1657.0000 - tn: 13404181.0000 - fp: 1043.0000 - fn: 89535.0000 - precision: 0.6137 - recall: 0.0182 - auc: 0.9123 - val_loss: 6.1618 - val_accuracy: 0.0267 - val_tp: 27.0000 - val_tn: 1672635.0000 - val_fp: 78.0000 - val_fn: 11352.0000 - val_precision: 0.2571 - val_recall: 0.0024 - val_auc: 0.6779
# Epoch 25/100
# 2850/2850 [==============================] - 280s 98ms/step - loss: 3.2898 - accuracy: 0.1290 - tp: 1846.0000 - tn: 13404089.0000 - fp: 1135.0000 - fn: 89346.0000 - precision: 0.6193 - recall: 0.0202 - auc: 0.9151 - val_loss: 5.8584 - val_accuracy: 0.0262 - val_tp: 19.0000 - val_tn: 1672648.0000 - val_fp: 65.0000 - val_fn: 11360.0000 - val_precision: 0.2262 - val_recall: 0.0017 - val_auc: 0.6793
# Epoch 26/100
# 2850/2850 [==============================] - 293s 103ms/step - loss: 3.2177 - accuracy: 0.1381 - tp: 2130.0000 - tn: 13403999.0000 - fp: 1225.0000 - fn: 89062.0000 - precision: 0.6349 - recall: 0.0234 - auc: 0.9202 - val_loss: 6.2671 - val_accuracy: 0.0264 - val_tp: 33.0000 - val_tn: 1672605.0000 - val_fp: 108.0000 - val_fn: 11346.0000 - val_precision: 0.2340 - val_recall: 0.0029 - val_auc: 0.6770
# Epoch 27/100
# 2850/2850 [==============================] - 307s 107ms/step - loss: 3.2008 - accuracy: 0.1411 - tp: 2215.0000 - tn: 13403917.0000 - fp: 1307.0000 - fn: 88977.0000 - precision: 0.6289 - recall: 0.0243 - auc: 0.9213 - val_loss: 6.0250 - val_accuracy: 0.0265 - val_tp: 21.0000 - val_tn: 1672649.0000 - val_fp: 64.0000 - val_fn: 11358.0000 - val_precision: 0.2471 - val_recall: 0.0018 - val_auc: 0.6741
# Epoch 28/100
# 2850/2850 [==============================] - 307s 107ms/step - loss: 3.1128 - accuracy: 0.1514 - tp: 2475.0000 - tn: 13403804.0000 - fp: 1420.0000 - fn: 88717.0000 - precision: 0.6354 - recall: 0.0271 - auc: 0.9268 - val_loss: 6.2553 - val_accuracy: 0.0267 - val_tp: 28.0000 - val_tn: 1672617.0000 - val_fp: 96.0000 - val_fn: 11351.0000 - val_precision: 0.2258 - val_recall: 0.0025 - val_auc: 0.6707
# Epoch 29/100
# 2850/2850 [==============================] - 264s 92ms/step - loss: 3.0950 - accuracy: 0.1554 - tp: 2609.0000 - tn: 13403675.0000 - fp: 1549.0000 - fn: 88583.0000 - precision: 0.6275 - recall: 0.0286 - auc: 0.9279 - val_loss: 6.2556 - val_accuracy: 0.0259 - val_tp: 23.0000 - val_tn: 1672607.0000 - val_fp: 106.0000 - val_fn: 11356.0000 - val_precision: 0.1783 - val_recall: 0.0020 - val_auc: 0.6730
# Epoch 30/100
# 2850/2850 [==============================] - 208s 73ms/step - loss: 3.0402 - accuracy: 0.1649 - tp: 2854.0000 - tn: 13403607.0000 - fp: 1617.0000 - fn: 88338.0000 - precision: 0.6383 - recall: 0.0313 - auc: 0.9307 - val_loss: 6.5659 - val_accuracy: 0.0284 - val_tp: 27.0000 - val_tn: 1672596.0000 - val_fp: 117.0000 - val_fn: 11352.0000 - val_precision: 0.1875 - val_recall: 0.0024 - val_auc: 0.6693
# Epoch 31/100
# 2850/2850 [==============================] - 270s 94ms/step - loss: 3.0115 - accuracy: 0.1702 - tp: 2929.0000 - tn: 13403456.0000 - fp: 1768.0000 - fn: 88263.0000 - precision: 0.6236 - recall: 0.0321 - auc: 0.9314 - val_loss: 6.5754 - val_accuracy: 0.0246 - val_tp: 17.0000 - val_tn: 1672633.0000 - val_fp: 80.0000 - val_fn: 11362.0000 - val_precision: 0.1753 - val_recall: 0.0015 - val_auc: 0.6566
# Epoch 32/100
# 2850/2850 [==============================] - 278s 97ms/step - loss: 2.9595 - accuracy: 0.1782 - tp: 3224.0000 - tn: 13403458.0000 - fp: 1766.0000 - fn: 87968.0000 - precision: 0.6461 - recall: 0.0354 - auc: 0.9353 - val_loss: 6.6230 - val_accuracy: 0.0253 - val_tp: 27.0000 - val_tn: 1672577.0000 - val_fp: 136.0000 - val_fn: 11352.0000 - val_precision: 0.1656 - val_recall: 0.0024 - val_auc: 0.6633
# Epoch 33/100
# 2850/2850 [==============================] - 227s 79ms/step - loss: 2.9225 - accuracy: 0.1875 - tp: 3521.0000 - tn: 13403303.0000 - fp: 1921.0000 - fn: 87671.0000 - precision: 0.6470 - recall: 0.0386 - auc: 0.9371 - val_loss: 6.6502 - val_accuracy: 0.0275 - val_tp: 25.0000 - val_tn: 1672575.0000 - val_fp: 138.0000 - val_fn: 11354.0000 - val_precision: 0.1534 - val_recall: 0.0022 - val_auc: 0.6594
# Epoch 34/100
# 2850/2850 [==============================] - 258s 90ms/step - loss: 2.8883 - accuracy: 0.1909 - tp: 3642.0000 - tn: 13403221.0000 - fp: 2003.0000 - fn: 87550.0000 - precision: 0.6452 - recall: 0.0399 - auc: 0.9388 - val_loss: 6.8460 - val_accuracy: 0.0284 - val_tp: 28.0000 - val_tn: 1672595.0000 - val_fp: 118.0000 - val_fn: 11351.0000 - val_precision: 0.1918 - val_recall: 0.0025 - val_auc: 0.6597
# Epoch 35/100
# 2850/2850 [==============================] - 315s 110ms/step - loss: 2.9190 - accuracy: 0.1939 - tp: 3686.0000 - tn: 13403195.0000 - fp: 2029.0000 - fn: 87506.0000 - precision: 0.6450 - recall: 0.0404 - auc: 0.9363 - val_loss: 6.8331 - val_accuracy: 0.0269 - val_tp: 22.0000 - val_tn: 1672567.0000 - val_fp: 146.0000 - val_fn: 11357.0000 - val_precision: 0.1310 - val_recall: 0.0019 - val_auc: 0.6620
# Epoch 36/100
# 2850/2850 [==============================] - 311s 109ms/step - loss: 2.8219 - accuracy: 0.2045 - tp: 4101.0000 - tn: 13403031.0000 - fp: 2193.0000 - fn: 87091.0000 - precision: 0.6516 - recall: 0.0450 - auc: 0.9422 - val_loss: 6.8121 - val_accuracy: 0.0266 - val_tp: 17.0000 - val_tn: 1672619.0000 - val_fp: 94.0000 - val_fn: 11362.0000 - val_precision: 0.1532 - val_recall: 0.0015 - val_auc: 0.6566
# Epoch 37/100
# Epoch 50/100
# 2850/2850 [==============================] - 248s 87ms/step - loss: 2.4873 - accuracy: 0.2743 - tp: 7284.0000 - tn: 13401954.0000 - fp: 3270.0000 - fn: 83908.0000 - precision: 0.6902 - recall: 0.0799 - auc: 0.9552 - val_loss: 7.7532 - val_accuracy: 0.0235 - val_tp: 23.0000 - val_tn: 1672519.0000 - val_fp: 194.0000 - val_fn: 11356.0000 - val_precision: 0.1060 - val_recall: 0.0020 - val_auc: 0.6391
# Epoch 51/100
# 2850/2850 [==============================] - 242s 85ms/step - loss: 2.5021 - accuracy: 0.2764 - tp: 7267.0000 - tn: 13401934.0000 - fp: 3290.0000 - fn: 83925.0000 - precision: 0.6884 - recall: 0.0797 - auc: 0.9543 - val_loss: 7.8243 - val_accuracy: 0.0284 - val_tp: 37.0000 - val_tn: 1672474.0000 - val_fp: 239.0000 - val_fn: 11342.0000 - val_precision: 0.1341 - val_recall: 0.0033 - val_auc: 0.6394
# Epoch 52/100
# 2850/2850 [==============================] - 300s 105ms/step - loss: 2.4504 - accuracy: 0.2836 - tp: 7916.0000 - tn: 13401779.0000 - fp: 3445.0000 - fn: 83276.0000 - precision: 0.6968 - recall: 0.0868 - auc: 0.9558 - val_loss: 8.1045 - val_accuracy: 0.0286 - val_tp: 32.0000 - val_tn: 1672455.0000 - val_fp: 258.0000 - val_fn: 11347.0000 - val_precision: 0.1103 - val_recall: 0.0028 - val_auc: 0.6350
# Epoch 53/100
# 2850/2850 [==============================] - 312s 109ms/step - loss: 2.4505 - accuracy: 0.2864 - tp: 8058.0000 - tn: 13401719.0000 - fp: 3505.0000 - fn: 83134.0000 - precision: 0.6969 - recall: 0.0884 - auc: 0.9555 - val_loss: 7.9443 - val_accuracy: 0.0278 - val_tp: 36.0000 - val_tn: 1672527.0000 - val_fp: 186.0000 - val_fn: 11343.0000 - val_precision: 0.1622 - val_recall: 0.0032 - val_auc: 0.6339
# Epoch 54/100
# 2850/2850 [==============================] - 307s 107ms/step - loss: 2.4252 - accuracy: 0.2940 - tp: 8437.0000 - tn: 13401677.0000 - fp: 3547.0000 - fn: 82755.0000 - precision: 0.7040 - recall: 0.0925 - auc: 0.9564 - val_loss: 8.3066 - val_accuracy: 0.0265 - val_tp: 29.0000 - val_tn: 1672460.0000 - val_fp: 253.0000 - val_fn: 11350.0000 - val_precision: 0.1028 - val_recall: 0.0025 - val_auc: 0.6345
# Epoch 55/100
# 2850/2850 [==============================] - 287s 100ms/step - loss: 2.5042 - accuracy: 0.2879 - tp: 8363.0000 - tn: 13401596.0000 - fp: 3628.0000 - fn: 82829.0000 - precision: 0.6974 - recall: 0.0917 - auc: 0.9551 - val_loss: 8.2696 - val_accuracy: 0.0278 - val_tp: 34.0000 - val_tn: 1672460.0000 - val_fp: 253.0000 - val_fn: 11345.0000 - val_precision: 0.1185 - val_recall: 0.0030 - val_auc: 0.6323
# Epoch 56/100
# 2850/2850 [==============================] - 327s 115ms/step - loss: 2.1215 - accuracy: 0.3847 - tp: 15263.0000 - tn: 13400198.0000 - fp: 5026.0000 - fn: 75929.0000 - precision: 0.7523 - recall: 0.1674 - auc: 0.9648 - val_loss: 10.3995 - val_accuracy: 0.0294 - val_tp: 57.0000 - val_tn: 1672087.0000 - val_fp: 626.0000 - val_fn: 11322.0000 - val_precision: 0.0835 - val_recall: 0.0050 - val_auc: 0.6116
# Epoch 89/100
# 2850/2850 [==============================] - 345s 121ms/step - loss: 2.0565 - accuracy: 0.3954 - tp: 16092.0000 - tn: 13400039.0000 - fp: 5185.0000 - fn: 75100.0000 - precision: 0.7563 - recall: 0.1765 - auc: 0.9667 - val_loss: 10.4356 - val_accuracy: 0.0273 - val_tp: 44.0000 - val_tn: 1672121.0000 - val_fp: 592.0000 - val_fn: 11335.0000 - val_precision: 0.0692 - val_recall: 0.0039 - val_auc: 0.6125
# Epoch 90/100
# 2850/2850 [==============================] - 310s 108ms/step - loss: 2.0851 - accuracy: 0.3894 - tp: 16080.0000 - tn: 13399839.0000 - fp: 5385.0000 - fn: 75112.0000 - precision: 0.7491 - recall: 0.1763 - auc: 0.9656 - val_loss: 9.8673 - val_accuracy: 0.0256 - val_tp: 31.0000 - val_tn: 1672334.0000 - val_fp: 379.0000 - val_fn: 11348.0000 - val_precision: 0.0756 - val_recall: 0.0027 - val_auc: 0.6083
# Epoch 91/100
# 2850/2850 [==============================] - 214s 75ms/step - loss: 2.0350 - accuracy: 0.4001 - tp: 16365.0000 - tn: 13399916.0000 - fp: 5308.0000 - fn: 74827.0000 - precision: 0.7551 - recall: 0.1795 - auc: 0.9673 - val_loss: 10.3895 - val_accuracy: 0.0254 - val_tp: 53.0000 - val_tn: 1672116.0000 - val_fp: 597.0000 - val_fn: 11326.0000 - val_precision: 0.0815 - val_recall: 0.0047 - val_auc: 0.6071
# Epoch 92/100
# 2850/2850 [==============================] - 238s 83ms/step - loss: 2.1433 - accuracy: 0.3792 - tp: 15371.0000 - tn: 13400165.0000 - fp: 5059.0000 - fn: 75821.0000 - precision: 0.7524 - recall: 0.1686 - auc: 0.9630 - val_loss: 10.0162 - val_accuracy: 0.0250 - val_tp: 43.0000 - val_tn: 1672204.0000 - val_fp: 509.0000 - val_fn: 11336.0000 - val_precision: 0.0779 - val_recall: 0.0038 - val_auc: 0.6130
# Epoch 93/100
# 2850/2850 [==============================] - 238s 83ms/step - loss: 2.0889 - accuracy: 0.3912 - tp: 15920.0000 - tn: 13399894.0000 - fp: 5330.0000 - fn: 75272.0000 - precision: 0.7492 - recall: 0.1746 - auc: 0.9656 - val_loss: 10.0374 - val_accuracy: 0.0299 - val_tp: 55.0000 - val_tn: 1672202.0000 - val_fp: 511.0000 - val_fn: 11324.0000 - val_precision: 0.0972 - val_recall: 0.0048 - val_auc: 0.6106
# Epoch 94/100
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-151b5aef4d41> in <module>()
#       2 history_148 = model_148.fit(train_df , epochs=100 , batch_size=5 , validation_data=val_df , verbose=1)
#       3 with open('model_148_history' , 'wb') as file:
# ----> 4  dump(history_148.history, file)
#
# NameError: name 'dump' is not defined

# %%
#save the model for reuse and comparing 
model_148.save('model148')
# Out:
# INFO:tensorflow:Assets written to: model148/assets

# %%
# evaluate the model 
model_148.evaluate(test_df_148)

#make predictions 
predictions_148 = model_148.predict(test_df_148)
# Out:
# 358/358 [==============================] - 1356s 4s/step - loss: 9.6852 - accuracy: 0.0299 - tp: 52.0000 - tn: 1681137.0000 - fp: 396.0000 - fn: 11387.0000 - precision: 0.1161 - recall: 0.0045 - auc: 0.6142

# %% [markdown]
# ## Model 2 with 36 Classes

# %% [markdown]
# ### Creating the traning and test dataframes using keras

# %%
# creatnig the training, testing and validation 
train_df_36 = image_dataset_from_directory(
    directory = 'veg_fruits/train',
    labels = 'inferred',
    label_mode = 'categorical',
    seed = 5,
    color_mode="rgb",
    shuffle = True ,
    batch_size = 32 ,
    image_size = (200,200)

    )

test_df_36 = image_dataset_from_directory(
    directory = 'veg_fruits/test',
    labels = 'inferred',
    label_mode = 'categorical',
    seed = 5,
    color_mode="rgb",
    shuffle = True ,
    batch_size = 32 ,
    image_size = (200,200)
    )

val_df_36 = image_dataset_from_directory(
    directory = 'veg_fruits/validation',
    labels = 'inferred',
    label_mode = 'categorical',
    seed = 5,
    color_mode="rgb",
    shuffle = True ,
    batch_size = 32 ,
    image_size = (200,200)
    )
# Out:
# Found 2914 files belonging to 36 classes.
# Found 571 files belonging to 36 classes.
# Found 563 files belonging to 36 classes.

# %%
labels_36 = test_df_36.class_names
labels_36_df = pd.DataFrame(labels_36)
labels_36_df.columns =['ingredient']
labels_36_df
labels_36_df.to_csv('labels_36.csv')

# %% [markdown]
# ### Visualizing the data

# %%
# plotting a sample of the images
plt.figure(figsize=(10,10))

for image , label in train_df_36.take(1):
    for i in range(6):
        ax = plt.subplot(3 ,3, i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.axis('off')

# %% [markdown]
# ### Define the model architecture and fitting the model

# %%
# The model will be a multi layer Conv2D and Maxpooling with Dropouts to help prevent overfitting , towrds the end 1 Dens layer will be there before our final output
model_36 = Sequential()
#layer 1,2,3 sequence 
model_36.add(Conv2D(filters= 32, kernel_size=(3,3),activation='relu',input_shape = (200, 200, 3)))
model_36.add(MaxPooling2D((2,2)))
model_36.add(Dropout(0.2))
#layer 4,5,6 sequence 
model_36.add(Conv2D(filters= 64, kernel_size=(3,3),activation='relu'))
model_36.add(MaxPooling2D((2,2)))
model_36.add(Dropout(0.2))

#Dense Network
model_36.add(Flatten())
model_36.add(Dense(3000,activation='relu'))
model_36.add(Dense(1500,activation='relu'))
model_36.add(Dropout(0.25))
model_36.add(Dense(500,activation='relu'))
#output layer with 36 classifications 
model_36.add(Dense(36,activation='softmax'))

# compile the model_36 using the adam optimizer and categorical crossentropy for loss as we are using one-hot encoding style catagories
model_36.compile(optimizer='adam' , 
              loss='categorical_crossentropy' ,
              metrics=[
                    'accuracy',
                    tf.keras.metrics.TruePositives(name="tp"),
                    tf.keras.metrics.TrueNegatives(name="tn"),
                    tf.keras.metrics.FalsePositives(name="fp"),
                    tf.keras.metrics.FalseNegatives(name="fn"),
                    tf.keras.metrics.Precision(name="precision"),
                    tf.keras.metrics.Recall(name="recall"),
                    tf.keras.metrics.AUC(name="auc"),
                    ]
            )


# printing out a summary of the model_36 
model_36.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 198, 198, 32)      896
#
#  max_pooling2d_2 (MaxPooling  (None, 99, 99, 32)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 99, 99, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 97, 97, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 48, 48, 64)       0
#  2D)
#
#  dropout_3 (Dropout)         (None, 48, 48, 64)        0
#
#  flatten_1 (Flatten)         (None, 147456)            0
#
#  dense_4 (Dense)             (None, 3000)              442371000
#
#  dense_5 (Dense)             (None, 1500)              4501500
#
#  dropout_4 (Dropout)         (None, 1500)              0
#
#  dense_6 (Dense)             (None, 500)               750500
#
#  dense_7 (Dense)             (None, 36)                18036
#
# =================================================================
# Total params: 447,660,428
# Trainable params: 447,660,428
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting the model with our traning dataset
history_36 = model_36.fit(train_df_36 , epochs=100 , batch_size=10 , validation_data=val_df , verbose=1)
with open('model_36_history' , 'wb') as file:
 pkl.dump(history_36.history, file)
# Out:
# Epoch 1/100
# 92/92 [==============================] - 442s 5s/step - loss: 487.7014 - accuracy: 0.0456 - tp: 17.0000 - tn: 101450.0000 - fp: 540.0000 - fn: 2897.0000 - precision: 0.0305 - recall: 0.0058 - auc: 0.5132 - val_loss: 3.5979 - val_accuracy: 0.0231 - val_tp: 0.0000e+00 - val_tn: 19704.0000 - val_fp: 1.0000 - val_fn: 563.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5096
# Epoch 2/100
# 92/92 [==============================] - 44s 448ms/step - loss: 3.5236 - accuracy: 0.0528 - tp: 2.0000 - tn: 101972.0000 - fp: 18.0000 - fn: 2912.0000 - precision: 0.1000 - recall: 6.8634e-04 - auc: 0.6072 - val_loss: 3.6658 - val_accuracy: 0.0355 - val_tp: 0.0000e+00 - val_tn: 19705.0000 - val_fp: 0.0000e+00 - val_fn: 563.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4092
# Epoch 3/100
# 92/92 [==============================] - 44s 449ms/step - loss: 3.3588 - accuracy: 0.0920 - tp: 22.0000 - tn: 101947.0000 - fp: 43.0000 - fn: 2892.0000 - precision: 0.3385 - recall: 0.0075 - auc: 0.6958 - val_loss: 3.9891 - val_accuracy: 0.1083 - val_tp: 10.0000 - val_tn: 19704.0000 - val_fp: 1.0000 - val_fn: 553.0000 - val_precision: 0.9091 - val_recall: 0.0178 - val_auc: 0.4256
# Epoch 4/100
# 92/92 [==============================] - 43s 444ms/step - loss: 3.0564 - accuracy: 0.1747 - tp: 149.0000 - tn: 101912.0000 - fp: 78.0000 - fn: 2765.0000 - precision: 0.6564 - recall: 0.0511 - auc: 0.7754 - val_loss: 4.0578 - val_accuracy: 0.1847 - val_tp: 55.0000 - val_tn: 19700.0000 - val_fp: 5.0000 - val_fn: 508.0000 - val_precision: 0.9167 - val_recall: 0.0977 - val_auc: 0.5125
# Epoch 5/100
# 92/92 [==============================] - 43s 441ms/step - loss: 2.6010 - accuracy: 0.3113 - tp: 513.0000 - tn: 101862.0000 - fp: 128.0000 - fn: 2401.0000 - precision: 0.8003 - recall: 0.1760 - auc: 0.8509 - val_loss: 4.3110 - val_accuracy: 0.2984 - val_tp: 131.0000 - val_tn: 19675.0000 - val_fp: 30.0000 - val_fn: 432.0000 - val_precision: 0.8137 - val_recall: 0.2327 - val_auc: 0.6093
# Epoch 6/100
# 92/92 [==============================] - 43s 444ms/step - loss: 2.1026 - accuracy: 0.4808 - tp: 1011.0000 - tn: 101833.0000 - fp: 157.0000 - fn: 1903.0000 - precision: 0.8656 - recall: 0.3469 - auc: 0.9130 - val_loss: 4.0652 - val_accuracy: 0.3694 - val_tp: 162.0000 - val_tn: 19666.0000 - val_fp: 39.0000 - val_fn: 401.0000 - val_precision: 0.8060 - val_recall: 0.2877 - val_auc: 0.6540
# Epoch 7/100
# 92/92 [==============================] - 43s 445ms/step - loss: 1.5511 - accuracy: 0.6122 - tp: 1470.0000 - tn: 101846.0000 - fp: 144.0000 - fn: 1444.0000 - precision: 0.9108 - recall: 0.5045 - auc: 0.9483 - val_loss: 4.8034 - val_accuracy: 0.4387 - val_tp: 216.0000 - val_tn: 19645.0000 - val_fp: 60.0000 - val_fn: 347.0000 - val_precision: 0.7826 - val_recall: 0.3837 - val_auc: 0.6866
# Epoch 8/100
# 92/92 [==============================] - 43s 442ms/step - loss: 1.3270 - accuracy: 0.6922 - tp: 1776.0000 - tn: 101841.0000 - fp: 149.0000 - fn: 1138.0000 - precision: 0.9226 - recall: 0.6095 - auc: 0.9659 - val_loss: 5.2719 - val_accuracy: 0.4316 - val_tp: 224.0000 - val_tn: 19640.0000 - val_fp: 65.0000 - val_fn: 339.0000 - val_precision: 0.7751 - val_recall: 0.3979 - val_auc: 0.6825
# Epoch 9/100
# 92/92 [==============================] - 43s 448ms/step - loss: 1.0833 - accuracy: 0.7437 - tp: 1967.0000 - tn: 101811.0000 - fp: 179.0000 - fn: 947.0000 - precision: 0.9166 - recall: 0.6750 - auc: 0.9734 - val_loss: 4.9825 - val_accuracy: 0.4707 - val_tp: 250.0000 - val_tn: 19616.0000 - val_fp: 89.0000 - val_fn: 313.0000 - val_precision: 0.7375 - val_recall: 0.4440 - val_auc: 0.7309
# Epoch 10/100
# 92/92 [==============================] - 42s 433ms/step - loss: 0.8237 - accuracy: 0.8061 - tp: 2178.0000 - tn: 101824.0000 - fp: 166.0000 - fn: 736.0000 - precision: 0.9292 - recall: 0.7474 - auc: 0.9819 - val_loss: 6.0001 - val_accuracy: 0.4671 - val_tp: 255.0000 - val_tn: 19579.0000 - val_fp: 126.0000 - val_fn: 308.0000 - val_precision: 0.6693 - val_recall: 0.4529 - val_auc: 0.7357
# Epoch 11/100
# 92/92 [==============================] - 43s 441ms/step - loss: 0.4742 - accuracy: 0.9331 - tp: 2660.0000 - tn: 101886.0000 - fp: 104.0000 - fn: 254.0000 - precision: 0.9624 - recall: 0.9128 - auc: 0.9930 - val_loss: 4.3510 - val_accuracy: 0.5524 - val_tp: 305.0000 - val_tn: 19577.0000 - val_fp: 128.0000 - val_fn: 258.0000 - val_precision: 0.7044 - val_recall: 0.5417 - val_auc: 0.7975
# Epoch 19/100
# 92/92 [==============================] - 44s 449ms/step - loss: 0.3107 - accuracy: 0.9375 - tp: 2679.0000 - tn: 101887.0000 - fp: 103.0000 - fn: 235.0000 - precision: 0.9630 - recall: 0.9194 - auc: 0.9941 - val_loss: 5.2335 - val_accuracy: 0.5453 - val_tp: 300.0000 - val_tn: 19568.0000 - val_fp: 137.0000 - val_fn: 263.0000 - val_precision: 0.6865 - val_recall: 0.5329 - val_auc: 0.7922
# Epoch 20/100
# 92/92 [==============================] - 43s 447ms/step - loss: 0.2286 - accuracy: 0.9485 - tp: 2735.0000 - tn: 101894.0000 - fp: 96.0000 - fn: 179.0000 - precision: 0.9661 - recall: 0.9386 - auc: 0.9942 - val_loss: 6.3058 - val_accuracy: 0.5595 - val_tp: 310.0000 - val_tn: 19540.0000 - val_fp: 165.0000 - val_fn: 253.0000 - val_precision: 0.6526 - val_recall: 0.5506 - val_auc: 0.7848
# Epoch 21/100
# 92/92 [==============================] - 43s 445ms/step - loss: 0.2489 - accuracy: 0.9533 - tp: 2752.0000 - tn: 101899.0000 - fp: 91.0000 - fn: 162.0000 - precision: 0.9680 - recall: 0.9444 - auc: 0.9944 - val_loss: 6.3828 - val_accuracy: 0.5400 - val_tp: 300.0000 - val_tn: 19542.0000 - val_fp: 163.0000 - val_fn: 263.0000 - val_precision: 0.6479 - val_recall: 0.5329 - val_auc: 0.7803
# Epoch 22/100
# 92/92 [==============================] - 43s 443ms/step - loss: 0.2528 - accuracy: 0.9557 - tp: 2755.0000 - tn: 101904.0000 - fp: 86.0000 - fn: 159.0000 - precision: 0.9697 - recall: 0.9454 - auc: 0.9954 - val_loss: 5.6831 - val_accuracy: 0.5577 - val_tp: 311.0000 - val_tn: 19557.0000 - val_fp: 148.0000 - val_fn: 252.0000 - val_precision: 0.6776 - val_recall: 0.5524 - val_auc: 0.7889
# Epoch 23/100
# 92/92 [==============================] - 43s 445ms/step - loss: 0.2955 - accuracy: 0.9523 - tp: 2736.0000 - tn: 101894.0000 - fp: 96.0000 - fn: 178.0000 - precision: 0.9661 - recall: 0.9389 - auc: 0.9943 - val_loss: 5.0873 - val_accuracy: 0.5613 - val_tp: 313.0000 - val_tn: 19545.0000 - val_fp: 160.0000 - val_fn: 250.0000 - val_precision: 0.6617 - val_recall: 0.5560 - val_auc: 0.8000
# Epoch 24/100
# 92/92 [==============================] - 43s 438ms/step - loss: 0.2291 - accuracy: 0.9592 - tp: 2765.0000 - tn: 101909.0000 - fp: 81.0000 - fn: 149.0000 - precision: 0.9715 - recall: 0.9489 - auc: 0.9952 - val_loss: 6.1105 - val_accuracy: 0.5737 - val_tp: 319.0000 - val_tn: 19533.0000 - val_fp: 172.0000 - val_fn: 244.0000 - val_precision: 0.6497 - val_recall: 0.5666 - val_auc: 0.7920
# Epoch 25/100
# 92/92 [==============================] - 43s 443ms/step - loss: 0.3651 - accuracy: 0.9451 - tp: 2716.0000 - tn: 101877.0000 - fp: 113.0000 - fn: 198.0000 - precision: 0.9601 - recall: 0.9321 - auc: 0.9933 - val_loss: 5.4033 - val_accuracy: 0.5631 - val_tp: 315.0000 - val_tn: 19544.0000 - val_fp: 161.0000 - val_fn: 248.0000 - val_precision: 0.6618 - val_recall: 0.5595 - val_auc: 0.7950
# Epoch 26/100
# 92/92 [==============================] - 42s 436ms/step - loss: 0.2052 - accuracy: 0.9640 - tp: 2787.0000 - tn: 101916.0000 - fp: 74.0000 - fn: 127.0000 - precision: 0.9741 - recall: 0.9564 - auc: 0.9967 - val_loss: 6.1031 - val_accuracy: 0.5666 - val_tp: 316.0000 - val_tn: 19526.0000 - val_fp: 179.0000 - val_fn: 247.0000 - val_precision: 0.6384 - val_recall: 0.5613 - val_auc: 0.7896
# Epoch 27/100
# 92/92 [==============================] - 42s 433ms/step - loss: 0.1333 - accuracy: 0.9688 - tp: 2808.0000 - tn: 101929.0000 - fp: 61.0000 - fn: 106.0000 - precision: 0.9787 - recall: 0.9636 - auc: 0.9972 - val_loss: 5.0804 - val_accuracy: 0.5666 - val_tp: 313.0000 - val_tn: 19545.0000 - val_fp: 160.0000 - val_fn: 250.0000 - val_precision: 0.6617 - val_recall: 0.5560 - val_auc: 0.7939
# Epoch 28/100
# 92/92 [==============================] - 42s 435ms/step - loss: 0.1132 - accuracy: 0.9729 - tp: 2817.0000 - tn: 101936.0000 - fp: 54.0000 - fn: 97.0000 - precision: 0.9812 - recall: 0.9667 - auc: 0.9976 - val_loss: 6.7638 - val_accuracy: 0.5684 - val_tp: 318.0000 - val_tn: 19528.0000 - val_fp: 177.0000 - val_fn: 245.0000 - val_precision: 0.6424 - val_recall: 0.5648 - val_auc: 0.7869
# Epoch 29/100
# 92/92 [==============================] - 42s 437ms/step - loss: 0.1421 - accuracy: 0.9739 - tp: 2827.0000 - tn: 101925.0000 - fp: 65.0000 - fn: 87.0000 - precision: 0.9775 - recall: 0.9701 - auc: 0.9962 - val_loss: 6.0257 - val_accuracy: 0.5702 - val_tp: 318.0000 - val_tn: 19535.0000 - val_fp: 170.0000 - val_fn: 245.0000 - val_precision: 0.6516 - val_recall: 0.5648 - val_auc: 0.7944
# Epoch 30/100
# 92/92 [==============================] - 42s 434ms/step - loss: 0.0958 - accuracy: 0.9798 - tp: 2852.0000 - tn: 101945.0000 - fp: 45.0000 - fn: 62.0000 - precision: 0.9845 - recall: 0.9787 - auc: 0.9975 - val_loss: 6.2880 - val_accuracy: 0.5826 - val_tp: 317.0000 - val_tn: 19523.0000 - val_fp: 182.0000 - val_fn: 246.0000 - val_precision: 0.6353 - val_recall: 0.5631 - val_auc: 0.7901
# Epoch 31/100
# 92/92 [==============================] - 44s 450ms/step - loss: 0.1019 - accuracy: 0.9777 - tp: 2840.0000 - tn: 101935.0000 - fp: 55.0000 - fn: 74.0000 - precision: 0.9810 - recall: 0.9746 - auc: 0.9970 - val_loss: 6.1226 - val_accuracy: 0.5560 - val_tp: 311.0000 - val_tn: 19532.0000 - val_fp: 173.0000 - val_fn: 252.0000 - val_precision: 0.6426 - val_recall: 0.5524 - val_auc: 0.7900
# Epoch 32/100
# 92/92 [==============================] - 44s 451ms/step - loss: 0.1135 - accuracy: 0.9770 - tp: 2832.0000 - tn: 101935.0000 - fp: 55.0000 - fn: 82.0000 - precision: 0.9809 - recall: 0.9719 - auc: 0.9969 - val_loss: 5.8422 - val_accuracy: 0.5719 - val_tp: 320.0000 - val_tn: 19541.0000 - val_fp: 164.0000 - val_fn: 243.0000 - val_precision: 0.6612 - val_recall: 0.5684 - val_auc: 0.7988
# Epoch 33/100
# 92/92 [==============================] - 44s 453ms/step - loss: 0.1279 - accuracy: 0.9725 - tp: 2816.0000 - tn: 101931.0000 - fp: 59.0000 - fn: 98.0000 - precision: 0.9795 - recall: 0.9664 - auc: 0.9964 - val_loss: 6.4032 - val_accuracy: 0.5808 - val_tp: 325.0000 - val_tn: 19534.0000 - val_fp: 171.0000 - val_fn: 238.0000 - val_precision: 0.6552 - val_recall: 0.5773 - val_auc: 0.7985
# Epoch 34/100
# 92/92 [==============================] - 43s 444ms/step - loss: 0.1704 - accuracy: 0.9684 - tp: 2807.0000 - tn: 101913.0000 - fp: 77.0000 - fn: 107.0000 - precision: 0.9733 - recall: 0.9633 - auc: 0.9955 - val_loss: 6.1374 - val_accuracy: 0.5755 - val_tp: 324.0000 - val_tn: 19531.0000 - val_fp: 174.0000 - val_fn: 239.0000 - val_precision: 0.6506 - val_recall: 0.5755 - val_auc: 0.7947
# Epoch 35/100
# 92/92 [==============================] - 43s 446ms/step - loss: 0.0942 - accuracy: 0.9791 - tp: 2844.0000 - tn: 101941.0000 - fp: 49.0000 - fn: 70.0000 - precision: 0.9831 - recall: 0.9760 - auc: 0.9973 - val_loss: 8.5572 - val_accuracy: 0.5790 - val_tp: 325.0000 - val_tn: 19509.0000 - val_fp: 196.0000 - val_fn: 238.0000 - val_precision: 0.6238 - val_recall: 0.5773 - val_auc: 0.7946
# Epoch 36/100
# 92/92 [==============================] - 44s 449ms/step - loss: 0.1391 - accuracy: 0.9767 - tp: 2841.0000 - tn: 101930.0000 - fp: 60.0000 - fn: 73.0000 - precision: 0.9793 - recall: 0.9749 - auc: 0.9959 - val_loss: 8.5705 - val_accuracy: 0.5719 - val_tp: 320.0000 - val_tn: 19508.0000 - val_fp: 197.0000 - val_fn: 243.0000 - val_precision: 0.6190 - val_recall: 0.5684 - val_auc: 0.7847
# Epoch 37/100
# 92/92 [==============================] - 44s 449ms/step - loss: 0.1610 - accuracy: 0.9715 - tp: 2816.0000 - tn: 101928.0000 - fp: 62.0000 - fn: 98.0000 - precision: 0.9785 - recall: 0.9664 - auc: 0.9952 - val_loss: 6.4230 - val_accuracy: 0.5755 - val_tp: 321.0000 - val_tn: 19517.0000 - val_fp: 188.0000 - val_fn: 242.0000 - val_precision: 0.6306 - val_recall: 0.5702 - val_auc: 0.8033
# Epoch 38/100
# 92/92 [==============================] - 44s 448ms/step - loss: 0.1242 - accuracy: 0.9784 - tp: 2844.0000 - tn: 101941.0000 - fp: 49.0000 - fn: 70.0000 - precision: 0.9831 - recall: 0.9760 - auc: 0.9977 - val_loss: 5.5234 - val_accuracy: 0.5897 - val_tp: 324.0000 - val_tn: 19528.0000 - val_fp: 177.0000 - val_fn: 239.0000 - val_precision: 0.6467 - val_recall: 0.5755 - val_auc: 0.8062
# Epoch 39/100
# 92/92 [==============================] - 43s 447ms/step - loss: 0.4831 - accuracy: 0.9187 - tp: 2634.0000 - tn: 101825.0000 - fp: 165.0000 - fn: 280.0000 - precision: 0.9411 - recall: 0.9039 - auc: 0.9884 - val_loss: 5.8097 - val_accuracy: 0.5933 - val_tp: 332.0000 - val_tn: 19520.0000 - val_fp: 185.0000 - val_fn: 231.0000 - val_precision: 0.6422 - val_recall: 0.5897 - val_auc: 0.8157
# Epoch 40/100
# 92/92 [==============================] - 44s 451ms/step - loss: 0.1907 - accuracy: 0.9605 - tp: 2778.0000 - tn: 101903.0000 - fp: 87.0000 - fn: 136.0000 - precision: 0.9696 - recall: 0.9533 - auc: 0.9953 - val_loss: 5.0163 - val_accuracy: 0.5773 - val_tp: 324.0000 - val_tn: 19551.0000 - val_fp: 154.0000 - val_fn: 239.0000 - val_precision: 0.6778 - val_recall: 0.5755 - val_auc: 0.8095
# Epoch 41/100
# 92/92 [==============================] - 43s 447ms/step - loss: 0.1472 - accuracy: 0.9667 - tp: 2785.0000 - tn: 101922.0000 - fp: 68.0000 - fn: 129.0000 - precision: 0.9762 - recall: 0.9557 - auc: 0.9974 - val_loss: 4.8929 - val_accuracy: 0.5897 - val_tp: 327.0000 - val_tn: 19540.0000 - val_fp: 165.0000 - val_fn: 236.0000 - val_precision: 0.6646 - val_recall: 0.5808 - val_auc: 0.8326
# Epoch 42/100
# 92/92 [==============================] - 44s 450ms/step - loss: 0.1197 - accuracy: 0.9770 - tp: 2830.0000 - tn: 101938.0000 - fp: 52.0000 - fn: 84.0000 - precision: 0.9820 - recall: 0.9712 - auc: 0.9969 - val_loss: 5.7005 - val_accuracy: 0.5773 - val_tp: 324.0000 - val_tn: 19519.0000 - val_fp: 186.0000 - val_fn: 239.0000 - val_precision: 0.6353 - val_recall: 0.5755 - val_auc: 0.7967
# Epoch 43/100
# 92/92 [==============================] - 43s 445ms/step - loss: 0.0728 - accuracy: 0.9804 - tp: 2853.0000 - tn: 101939.0000 - fp: 51.0000 - fn: 61.0000 - precision: 0.9824 - recall: 0.9791 - auc: 0.9982 - val_loss: 7.4110 - val_accuracy: 0.5826 - val_tp: 328.0000 - val_tn: 19505.0000 - val_fp: 200.0000 - val_fn: 235.0000 - val_precision: 0.6212 - val_recall: 0.5826 - val_auc: 0.7946
# Epoch 44/100
# 92/92 [==============================] - 44s 449ms/step - loss: 0.1141 - accuracy: 0.9818 - tp: 2856.0000 - tn: 101947.0000 - fp: 43.0000 - fn: 58.0000 - precision: 0.9852 - recall: 0.9801 - auc: 0.9979 - val_loss: 7.4945 - val_accuracy: 0.5755 - val_tp: 321.0000 - val_tn: 19513.0000 - val_fp: 192.0000 - val_fn: 242.0000 - val_precision: 0.6257 - val_recall: 0.5702 - val_auc: 0.7968
# Epoch 45/100
# 92/92 [==============================] - 43s 444ms/step - loss: 0.0873 - accuracy: 0.9787 - tp: 2844.0000 - tn: 101939.0000 - fp: 51.0000 - fn: 70.0000 - precision: 0.9824 - recall: 0.9760 - auc: 0.9982 - val_loss: 5.4478 - val_accuracy: 0.5826 - val_tp: 328.0000 - val_tn: 19502.0000 - val_fp: 203.0000 - val_fn: 235.0000 - val_precision: 0.6177 - val_recall: 0.5826 - val_auc: 0.8213
# Epoch 46/100
# 92/92 [==============================] - 43s 442ms/step - loss: 0.1345 - accuracy: 0.9767 - tp: 2835.0000 - tn: 101935.0000 - fp: 55.0000 - fn: 79.0000 - precision: 0.9810 - recall: 0.9729 - auc: 0.9985 - val_loss: 5.6693 - val_accuracy: 0.5950 - val_tp: 328.0000 - val_tn: 19520.0000 - val_fp: 185.0000 - val_fn: 235.0000 - val_precision: 0.6394 - val_recall: 0.5826 - val_auc: 0.8046
# Epoch 47/100
# 92/92 [==============================] - 43s 446ms/step - loss: 0.1274 - accuracy: 0.9770 - tp: 2839.0000 - tn: 101936.0000 - fp: 54.0000 - fn: 75.0000 - precision: 0.9813 - recall: 0.9743 - auc: 0.9977 - val_loss: 7.4306 - val_accuracy: 0.5826 - val_tp: 324.0000 - val_tn: 19518.0000 - val_fp: 187.0000 - val_fn: 239.0000 - val_precision: 0.6341 - val_recall: 0.5755 - val_auc: 0.7940
# Epoch 48/100
# 92/92 [==============================] - 43s 446ms/step - loss: 0.1014 - accuracy: 0.9787 - tp: 2843.0000 - tn: 101937.0000 - fp: 53.0000 - fn: 71.0000 - precision: 0.9817 - recall: 0.9756 - auc: 0.9986 - val_loss: 6.7254 - val_accuracy: 0.5790 - val_tp: 325.0000 - val_tn: 19517.0000 - val_fp: 188.0000 - val_fn: 238.0000 - val_precision: 0.6335 - val_recall: 0.5773 - val_auc: 0.7992
# Epoch 49/100
# 92/92 [==============================] - 43s 445ms/step - loss: 0.0439 - accuracy: 0.9842 - tp: 2867.0000 - tn: 101946.0000 - fp: 44.0000 - fn: 47.0000 - precision: 0.9849 - recall: 0.9839 - auc: 0.9993 - val_loss: 5.5455 - val_accuracy: 0.5844 - val_tp: 327.0000 - val_tn: 19516.0000 - val_fp: 189.0000 - val_fn: 236.0000 - val_precision: 0.6337 - val_recall: 0.5808 - val_auc: 0.8120
# Epoch 50/100
# 92/92 [==============================] - 43s 442ms/step - loss: 0.1229 - accuracy: 0.9753 - tp: 2833.0000 - tn: 101930.0000 - fp: 60.0000 - fn: 81.0000 - precision: 0.9793 - recall: 0.9722 - auc: 0.9973 - val_loss: 6.7781 - val_accuracy: 0.5773 - val_tp: 323.0000 - val_tn: 19526.0000 - val_fp: 179.0000 - val_fn: 240.0000 - val_precision: 0.6434 - val_recall: 0.5737 - val_auc: 0.7986
# Epoch 51/100
# 92/92 [==============================] - 43s 445ms/step - loss: 0.1128 - accuracy: 0.9815 - tp: 2858.0000 - tn: 101938.0000 - fp: 52.0000 - fn: 56.0000 - precision: 0.9821 - recall: 0.9808 - auc: 0.9975 - val_loss: 5.2246 - val_accuracy: 0.5915 - val_tp: 330.0000 - val_tn: 19524.0000 - val_fp: 181.0000 - val_fn: 233.0000 - val_precision: 0.6458 - val_recall: 0.5861 - val_auc: 0.8245
# Epoch 52/100
# 92/92 [==============================] - 44s 449ms/step - loss: 0.0632 - accuracy: 0.9811 - tp: 2849.0000 - tn: 101947.0000 - fp: 43.0000 - fn: 65.0000 - precision: 0.9851 - recall: 0.9777 - auc: 0.9989 - val_loss: 4.9117 - val_accuracy: 0.6021 - val_tp: 337.0000 - val_tn: 19508.0000 - val_fp: 197.0000 - val_fn: 226.0000 - val_precision: 0.6311 - val_recall: 0.5986 - val_auc: 0.8323
# Epoch 53/100
# 92/92 [==============================] - 43s 447ms/step - loss: 0.0556 - accuracy: 0.9846 - tp: 2867.0000 - tn: 101950.0000 - fp: 40.0000 - fn: 47.0000 - precision: 0.9862 - recall: 0.9839 - auc: 0.9989 - val_loss: 5.4395 - val_accuracy: 0.5986 - val_tp: 329.0000 - val_tn: 19513.0000 - val_fp: 192.0000 - val_fn: 234.0000 - val_precision: 0.6315 - val_recall: 0.5844 - val_auc: 0.8277
# Epoch 54/100
# 92/92 [==============================] - 43s 443ms/step - loss: 0.0364 - accuracy: 0.9876 - tp: 2874.0000 - tn: 101957.0000 - fp: 33.0000 - fn: 40.0000 - precision: 0.9886 - recall: 0.9863 - auc: 0.9993 - val_loss: 5.7296 - val_accuracy: 0.5933 - val_tp: 333.0000 - val_tn: 19513.0000 - val_fp: 192.0000 - val_fn: 230.0000 - val_precision: 0.6343 - val_recall: 0.5915 - val_auc: 0.8200
# Epoch 55/100
# 92/92 [==============================] - 43s 446ms/step - loss: 0.0289 - accuracy: 0.9876 - tp: 2876.0000 - tn: 101959.0000 - fp: 31.0000 - fn: 38.0000 - precision: 0.9893 - recall: 0.9870 - auc: 0.9998 - val_loss: 7.1295 - val_accuracy: 0.5915 - val_tp: 331.0000 - val_tn: 19515.0000 - val_fp: 190.0000 - val_fn: 232.0000 - val_precision: 0.6353 - val_recall: 0.5879 - val_auc: 0.7965
# Epoch 56/100
# 92/92 [==============================] - 43s 443ms/step - loss: 0.0787 - accuracy: 0.9846 - tp: 2864.0000 - tn: 101947.0000 - fp: 43.0000 - fn: 50.0000 - precision: 0.9852 - recall: 0.9828 - auc: 0.9984 - val_loss: 7.0826 - val_accuracy: 0.5950 - val_tp: 332.0000 - val_tn: 19520.0000 - val_fp: 185.0000 - val_fn: 231.0000 - val_precision: 0.6422 - val_recall: 0.5897 - val_auc: 0.7988
# Epoch 57/100
# 92/92 [==============================] - 43s 447ms/step - loss: 0.0510 - accuracy: 0.9849 - tp: 2865.0000 - tn: 101952.0000 - fp: 38.0000 - fn: 49.0000 - precision: 0.9869 - recall: 0.9832 - auc: 0.9993 - val_loss: 8.8688 - val_accuracy: 0.5808 - val_tp: 325.0000 - val_tn: 19511.0000 - val_fp: 194.0000 - val_fn: 238.0000 - val_precision: 0.6262 - val_recall: 0.5773 - val_auc: 0.7889
# Epoch 58/100
# 92/92 [==============================] - 43s 445ms/step - loss: 0.0994 - accuracy: 0.9798 - tp: 2849.0000 - tn: 101940.0000 - fp: 50.0000 - fn: 65.0000 - precision: 0.9828 - recall: 0.9777 - auc: 0.9977 - val_loss: 7.4331 - val_accuracy: 0.5844 - val_tp: 329.0000 - val_tn: 19500.0000 - val_fp: 205.0000 - val_fn: 234.0000 - val_precision: 0.6161 - val_recall: 0.5844 - val_auc: 0.8028
# Epoch 59/100
# 92/92 [==============================] - 44s 450ms/step - loss: 0.0867 - accuracy: 0.9849 - tp: 2861.0000 - tn: 101949.0000 - fp: 41.0000 - fn: 53.0000 - precision: 0.9859 - recall: 0.9818 - auc: 0.9984 - val_loss: 10.1178 - val_accuracy: 0.5790 - val_tp: 325.0000 - val_tn: 19503.0000 - val_fp: 202.0000 - val_fn: 238.0000 - val_precision: 0.6167 - val_recall: 0.5773 - val_auc: 0.7877
# Epoch 60/100
# 92/92 [==============================] - 43s 444ms/step - loss: 0.2507 - accuracy: 0.9688 - tp: 2816.0000 - tn: 101913.0000 - fp: 77.0000 - fn: 98.0000 - precision: 0.9734 - recall: 0.9664 - auc: 0.9959 - val_loss: 11.4028 - val_accuracy: 0.5790 - val_tp: 324.0000 - val_tn: 19487.0000 - val_fp: 218.0000 - val_fn: 239.0000 - val_precision: 0.5978 - val_recall: 0.5755 - val_auc: 0.7852
# Epoch 61/100
# 92/92 [==============================] - 44s 447ms/step - loss: 0.2106 - accuracy: 0.9671 - tp: 2807.0000 - tn: 101915.0000 - fp: 75.0000 - fn: 107.0000 - precision: 0.9740 - recall: 0.9633 - auc: 0.9953 - val_loss: 8.1697 - val_accuracy: 0.5861 - val_tp: 329.0000 - val_tn: 19502.0000 - val_fp: 203.0000 - val_fn: 234.0000 - val_precision: 0.6184 - val_recall: 0.5844 - val_auc: 0.8099
# Epoch 62/100
# 92/92 [==============================] - 43s 441ms/step - loss: 0.1440 - accuracy: 0.9719 - tp: 2827.0000 - tn: 101918.0000 - fp: 72.0000 - fn: 87.0000 - precision: 0.9752 - recall: 0.9701 - auc: 0.9968 - val_loss: 7.0018 - val_accuracy: 0.5844 - val_tp: 326.0000 - val_tn: 19519.0000 - val_fp: 186.0000 - val_fn: 237.0000 - val_precision: 0.6367 - val_recall: 0.5790 - val_auc: 0.8043
# Epoch 63/100
# 92/92 [==============================] - 43s 444ms/step - loss: 0.1446 - accuracy: 0.9732 - tp: 2817.0000 - tn: 101931.0000 - fp: 59.0000 - fn: 97.0000 - precision: 0.9795 - recall: 0.9667 - auc: 0.9969 - val_loss: 7.2438 - val_accuracy: 0.5879 - val_tp: 329.0000 - val_tn: 19517.0000 - val_fp: 188.0000 - val_fn: 234.0000 - val_precision: 0.6364 - val_recall: 0.5844 - val_auc: 0.7992
# Epoch 64/100
# 92/92 [==============================] - 43s 447ms/step - loss: 0.1482 - accuracy: 0.9743 - tp: 2827.0000 - tn: 101930.0000 - fp: 60.0000 - fn: 87.0000 - precision: 0.9792 - recall: 0.9701 - auc: 0.9964 - val_loss: 7.3213 - val_accuracy: 0.5773 - val_tp: 322.0000 - val_tn: 19519.0000 - val_fp: 186.0000 - val_fn: 241.0000 - val_precision: 0.6339 - val_recall: 0.5719 - val_auc: 0.7963
# Epoch 65/100
# 92/92 [==============================] - 43s 441ms/step - loss: 0.1558 - accuracy: 0.9763 - tp: 2843.0000 - tn: 101932.0000 - fp: 58.0000 - fn: 71.0000 - precision: 0.9800 - recall: 0.9756 - auc: 0.9965 - val_loss: 8.5660 - val_accuracy: 0.5844 - val_tp: 329.0000 - val_tn: 19505.0000 - val_fp: 200.0000 - val_fn: 234.0000 - val_precision: 0.6219 - val_recall: 0.5844 - val_auc: 0.7976
# Epoch 66/100
# 92/92 [==============================] - 43s 446ms/step - loss: 0.1297 - accuracy: 0.9791 - tp: 2844.0000 - tn: 101940.0000 - fp: 50.0000 - fn: 70.0000 - precision: 0.9827 - recall: 0.9760 - auc: 0.9965 - val_loss: 5.7298 - val_accuracy: 0.5915 - val_tp: 332.0000 - val_tn: 19505.0000 - val_fp: 200.0000 - val_fn: 231.0000 - val_precision: 0.6241 - val_recall: 0.5897 - val_auc: 0.8129
# Epoch 67/100
# 92/92 [==============================] - 43s 444ms/step - loss: 0.0899 - accuracy: 0.9822 - tp: 2855.0000 - tn: 101942.0000 - fp: 48.0000 - fn: 59.0000 - precision: 0.9835 - recall: 0.9798 - auc: 0.9979 - val_loss: 7.5457 - val_accuracy: 0.5861 - val_tp: 330.0000 - val_tn: 19516.0000 - val_fp: 189.0000 - val_fn: 233.0000 - val_precision: 0.6358 - val_recall: 0.5861 - val_auc: 0.8040
# Epoch 68/100
# 92/92 [==============================] - 43s 443ms/step - loss: 0.0312 - accuracy: 0.9863 - tp: 2872.0000 - tn: 101953.0000 - fp: 37.0000 - fn: 42.0000 - precision: 0.9873 - recall: 0.9856 - auc: 0.9996 - val_loss: 8.4091 - val_accuracy: 0.5808 - val_tp: 327.0000 - val_tn: 19517.0000 - val_fp: 188.0000 - val_fn: 236.0000 - val_precision: 0.6350 - val_recall: 0.5808 - val_auc: 0.7906
# Epoch 69/100
# 92/92 [==============================] - 44s 450ms/step - loss: 0.0562 - accuracy: 0.9852 - tp: 2868.0000 - tn: 101949.0000 - fp: 41.0000 - fn: 46.0000 - precision: 0.9859 - recall: 0.9842 - auc: 0.9986 - val_loss: 7.6963 - val_accuracy: 0.5808 - val_tp: 323.0000 - val_tn: 19521.0000 - val_fp: 184.0000 - val_fn: 240.0000 - val_precision: 0.6371 - val_recall: 0.5737 - val_auc: 0.7965
# Epoch 70/100
# 92/92 [==============================] - 43s 446ms/step - loss: 0.1276 - accuracy: 0.9801 - tp: 2852.0000 - tn: 101940.0000 - fp: 50.0000 - fn: 62.0000 - precision: 0.9828 - recall: 0.9787 - auc: 0.9966 - val_loss: 9.6456 - val_accuracy: 0.5826 - val_tp: 327.0000 - val_tn: 19513.0000 - val_fp: 192.0000 - val_fn: 236.0000 - val_precision: 0.6301 - val_recall: 0.5808 - val_auc: 0.8026
# Epoch 71/100
# 92/92 [==============================] - 44s 449ms/step - loss: 0.1512 - accuracy: 0.9801 - tp: 2855.0000 - tn: 101945.0000 - fp: 45.0000 - fn: 59.0000 - precision: 0.9845 - recall: 0.9798 - auc: 0.9974 - val_loss: 13.0030 - val_accuracy: 0.5826 - val_tp: 328.0000 - val_tn: 19496.0000 - val_fp: 209.0000 - val_fn: 235.0000 - val_precision: 0.6108 - val_recall: 0.5826 - val_auc: 0.7882
# Epoch 72/100
# 92/92 [==============================] - 43s 444ms/step - loss: 0.2435 - accuracy: 0.9684 - tp: 2815.0000 - tn: 101916.0000 - fp: 74.0000 - fn: 99.0000 - precision: 0.9744 - recall: 0.9660 - auc: 0.9943 - val_loss: 11.4042 - val_accuracy: 0.5719 - val_tp: 319.0000 - val_tn: 19513.0000 - val_fp: 192.0000 - val_fn: 244.0000 - val_precision: 0.6243 - val_recall: 0.5666 - val_auc: 0.7853
# Epoch 73/100
# 92/92 [==============================] - 44s 452ms/step - loss: 0.2487 - accuracy: 0.9684 - tp: 2817.0000 - tn: 101919.0000 - fp: 71.0000 - fn: 97.0000 - precision: 0.9754 - recall: 0.9667 - auc: 0.9945 - val_loss: 11.7757 - val_accuracy: 0.5577 - val_tp: 313.0000 - val_tn: 19483.0000 - val_fp: 222.0000 - val_fn: 250.0000 - val_precision: 0.5850 - val_recall: 0.5560 - val_auc: 0.7872
# Epoch 74/100
# 92/92 [==============================] - 44s 449ms/step - loss: 0.2306 - accuracy: 0.9684 - tp: 2811.0000 - tn: 101916.0000 - fp: 74.0000 - fn: 103.0000 - precision: 0.9744 - recall: 0.9647 - auc: 0.9948 - val_loss: 10.3541 - val_accuracy: 0.5808 - val_tp: 326.0000 - val_tn: 19504.0000 - val_fp: 201.0000 - val_fn: 237.0000 - val_precision: 0.6186 - val_recall: 0.5790 - val_auc: 0.7860
# Epoch 75/100
# 92/92 [==============================] - 43s 447ms/step - loss: 0.5293 - accuracy: 0.9420 - tp: 2736.0000 - tn: 101877.0000 - fp: 113.0000 - fn: 178.0000 - precision: 0.9603 - recall: 0.9389 - auc: 0.9905 - val_loss: 9.6945 - val_accuracy: 0.5666 - val_tp: 317.0000 - val_tn: 19495.0000 - val_fp: 210.0000 - val_fn: 246.0000 - val_precision: 0.6015 - val_recall: 0.5631 - val_auc: 0.7914
# Epoch 76/100
# 92/92 [==============================] - 43s 445ms/step - loss: 0.2203 - accuracy: 0.9674 - tp: 2810.0000 - tn: 101915.0000 - fp: 75.0000 - fn: 104.0000 - precision: 0.9740 - recall: 0.9643 - auc: 0.9941 - val_loss: 9.1645 - val_accuracy: 0.5755 - val_tp: 324.0000 - val_tn: 19511.0000 - val_fp: 194.0000 - val_fn: 239.0000 - val_precision: 0.6255 - val_recall: 0.5755 - val_auc: 0.7917
# Epoch 77/100
# 92/92 [==============================] - 42s 435ms/step - loss: 0.2568 - accuracy: 0.9650 - tp: 2793.0000 - tn: 101916.0000 - fp: 74.0000 - fn: 121.0000 - precision: 0.9742 - recall: 0.9585 - auc: 0.9958 - val_loss: 7.6120 - val_accuracy: 0.5755 - val_tp: 324.0000 - val_tn: 19509.0000 - val_fp: 196.0000 - val_fn: 239.0000 - val_precision: 0.6231 - val_recall: 0.5755 - val_auc: 0.8085
# Epoch 78/100
# 92/92 [==============================] - 42s 435ms/step - loss: 0.1915 - accuracy: 0.9780 - tp: 2844.0000 - tn: 101935.0000 - fp: 55.0000 - fn: 70.0000 - precision: 0.9810 - recall: 0.9760 - auc: 0.9961 - val_loss: 4.9137 - val_accuracy: 0.6110 - val_tp: 343.0000 - val_tn: 19525.0000 - val_fp: 180.0000 - val_fn: 220.0000 - val_precision: 0.6558 - val_recall: 0.6092 - val_auc: 0.8486
# Epoch 79/100
# 92/92 [==============================] - 43s 443ms/step - loss: 0.0795 - accuracy: 0.9825 - tp: 2858.0000 - tn: 101946.0000 - fp: 44.0000 - fn: 56.0000 - precision: 0.9848 - recall: 0.9808 - auc: 0.9973 - val_loss: 6.7083 - val_accuracy: 0.5844 - val_tp: 328.0000 - val_tn: 19507.0000 - val_fp: 198.0000 - val_fn: 235.0000 - val_precision: 0.6236 - val_recall: 0.5826 - val_auc: 0.8087
# Epoch 80/100
# 92/92 [==============================] - 42s 431ms/step - loss: 0.1011 - accuracy: 0.9822 - tp: 2859.0000 - tn: 101945.0000 - fp: 45.0000 - fn: 55.0000 - precision: 0.9845 - recall: 0.9811 - auc: 0.9987 - val_loss: 7.1898 - val_accuracy: 0.5773 - val_tp: 324.0000 - val_tn: 19498.0000 - val_fp: 207.0000 - val_fn: 239.0000 - val_precision: 0.6102 - val_recall: 0.5755 - val_auc: 0.8081
# Epoch 81/100
# 92/92 [==============================] - 42s 434ms/step - loss: 0.3739 - accuracy: 0.9671 - tp: 2814.0000 - tn: 101904.0000 - fp: 86.0000 - fn: 100.0000 - precision: 0.9703 - recall: 0.9657 - auc: 0.9936 - val_loss: 9.2948 - val_accuracy: 0.5808 - val_tp: 327.0000 - val_tn: 19508.0000 - val_fp: 197.0000 - val_fn: 236.0000 - val_precision: 0.6240 - val_recall: 0.5808 - val_auc: 0.7997
# Epoch 82/100
# 92/92 [==============================] - 42s 432ms/step - loss: 0.3098 - accuracy: 0.9650 - tp: 2806.0000 - tn: 101897.0000 - fp: 93.0000 - fn: 108.0000 - precision: 0.9679 - recall: 0.9629 - auc: 0.9922 - val_loss: 8.9745 - val_accuracy: 0.5879 - val_tp: 329.0000 - val_tn: 19502.0000 - val_fp: 203.0000 - val_fn: 234.0000 - val_precision: 0.6184 - val_recall: 0.5844 - val_auc: 0.8108
# Epoch 83/100
# 92/92 [==============================] - 42s 434ms/step - loss: 0.2705 - accuracy: 0.9623 - tp: 2793.0000 - tn: 101900.0000 - fp: 90.0000 - fn: 121.0000 - precision: 0.9688 - recall: 0.9585 - auc: 0.9941 - val_loss: 6.8464 - val_accuracy: 0.5773 - val_tp: 324.0000 - val_tn: 19520.0000 - val_fp: 185.0000 - val_fn: 239.0000 - val_precision: 0.6365 - val_recall: 0.5755 - val_auc: 0.8058
# Epoch 84/100
# 92/92 [==============================] - 42s 434ms/step - loss: 0.2674 - accuracy: 0.9729 - tp: 2826.0000 - tn: 101926.0000 - fp: 64.0000 - fn: 88.0000 - precision: 0.9779 - recall: 0.9698 - auc: 0.9957 - val_loss: 7.8529 - val_accuracy: 0.5737 - val_tp: 321.0000 - val_tn: 19525.0000 - val_fp: 180.0000 - val_fn: 242.0000 - val_precision: 0.6407 - val_recall: 0.5702 - val_auc: 0.7935
# Epoch 85/100
# 92/92 [==============================] - 43s 437ms/step - loss: 0.2515 - accuracy: 0.9609 - tp: 2791.0000 - tn: 101898.0000 - fp: 92.0000 - fn: 123.0000 - precision: 0.9681 - recall: 0.9578 - auc: 0.9942 - val_loss: 5.9633 - val_accuracy: 0.5933 - val_tp: 333.0000 - val_tn: 19512.0000 - val_fp: 193.0000 - val_fn: 230.0000 - val_precision: 0.6331 - val_recall: 0.5915 - val_auc: 0.8268
# Epoch 86/100
# 92/92 [==============================] - 42s 435ms/step - loss: 0.2161 - accuracy: 0.9818 - tp: 2855.0000 - tn: 101946.0000 - fp: 44.0000 - fn: 59.0000 - precision: 0.9848 - recall: 0.9798 - auc: 0.9968 - val_loss: 7.6837 - val_accuracy: 0.5790 - val_tp: 325.0000 - val_tn: 19511.0000 - val_fp: 194.0000 - val_fn: 238.0000 - val_precision: 0.6262 - val_recall: 0.5773 - val_auc: 0.7988
# Epoch 87/100
# 92/92 [==============================] - 42s 433ms/step - loss: 0.0680 - accuracy: 0.9825 - tp: 2860.0000 - tn: 101944.0000 - fp: 46.0000 - fn: 54.0000 - precision: 0.9842 - recall: 0.9815 - auc: 0.9987 - val_loss: 7.9487 - val_accuracy: 0.5826 - val_tp: 327.0000 - val_tn: 19514.0000 - val_fp: 191.0000 - val_fn: 236.0000 - val_precision: 0.6313 - val_recall: 0.5808 - val_auc: 0.7990
# Epoch 88/100
# 92/92 [==============================] - 43s 436ms/step - loss: 0.0872 - accuracy: 0.9839 - tp: 2862.0000 - tn: 101952.0000 - fp: 38.0000 - fn: 52.0000 - precision: 0.9869 - recall: 0.9822 - auc: 0.9981 - val_loss: 6.6160 - val_accuracy: 0.5986 - val_tp: 330.0000 - val_tn: 19524.0000 - val_fp: 181.0000 - val_fn: 233.0000 - val_precision: 0.6458 - val_recall: 0.5861 - val_auc: 0.8235
# Epoch 89/100
# 92/92 [==============================] - 42s 435ms/step - loss: 0.0312 - accuracy: 0.9890 - tp: 2881.0000 - tn: 101960.0000 - fp: 30.0000 - fn: 33.0000 - precision: 0.9897 - recall: 0.9887 - auc: 0.9995 - val_loss: 7.2380 - val_accuracy: 0.6110 - val_tp: 340.0000 - val_tn: 19518.0000 - val_fp: 187.0000 - val_fn: 223.0000 - val_precision: 0.6452 - val_recall: 0.6039 - val_auc: 0.8238
# Epoch 90/100
# 92/92 [==============================] - 42s 436ms/step - loss: 0.1018 - accuracy: 0.9890 - tp: 2880.0000 - tn: 101962.0000 - fp: 28.0000 - fn: 34.0000 - precision: 0.9904 - recall: 0.9883 - auc: 0.9988 - val_loss: 6.8697 - val_accuracy: 0.5986 - val_tp: 330.0000 - val_tn: 19518.0000 - val_fp: 187.0000 - val_fn: 233.0000 - val_precision: 0.6383 - val_recall: 0.5861 - val_auc: 0.8155
# Epoch 91/100
# 92/92 [==============================] - 42s 436ms/step - loss: 0.1076 - accuracy: 0.9767 - tp: 2840.0000 - tn: 101934.0000 - fp: 56.0000 - fn: 74.0000 - precision: 0.9807 - recall: 0.9746 - auc: 0.9979 - val_loss: 10.3670 - val_accuracy: 0.5826 - val_tp: 326.0000 - val_tn: 19507.0000 - val_fp: 198.0000 - val_fn: 237.0000 - val_precision: 0.6221 - val_recall: 0.5790 - val_auc: 0.7953
# Epoch 92/100
# 92/92 [==============================] - 43s 437ms/step - loss: 0.1324 - accuracy: 0.9791 - tp: 2847.0000 - tn: 101937.0000 - fp: 53.0000 - fn: 67.0000 - precision: 0.9817 - recall: 0.9770 - auc: 0.9972 - val_loss: 9.5449 - val_accuracy: 0.5844 - val_tp: 327.0000 - val_tn: 19494.0000 - val_fp: 211.0000 - val_fn: 236.0000 - val_precision: 0.6078 - val_recall: 0.5808 - val_auc: 0.7952
# Epoch 93/100
# 92/92 [==============================] - 43s 438ms/step - loss: 0.0411 - accuracy: 0.9894 - tp: 2877.0000 - tn: 101965.0000 - fp: 25.0000 - fn: 37.0000 - precision: 0.9914 - recall: 0.9873 - auc: 0.9989 - val_loss: 8.3241 - val_accuracy: 0.5844 - val_tp: 329.0000 - val_tn: 19504.0000 - val_fp: 201.0000 - val_fn: 234.0000 - val_precision: 0.6208 - val_recall: 0.5844 - val_auc: 0.7984
# Epoch 94/100
# 92/92 [==============================] - 43s 440ms/step - loss: 0.0346 - accuracy: 0.9873 - tp: 2875.0000 - tn: 101961.0000 - fp: 29.0000 - fn: 39.0000 - precision: 0.9900 - recall: 0.9866 - auc: 0.9995 - val_loss: 12.7236 - val_accuracy: 0.5826 - val_tp: 328.0000 - val_tn: 19481.0000 - val_fp: 224.0000 - val_fn: 235.0000 - val_precision: 0.5942 - val_recall: 0.5826 - val_auc: 0.7974
# Epoch 95/100
# 92/92 [==============================] - 43s 440ms/step - loss: 0.1378 - accuracy: 0.9784 - tp: 2850.0000 - tn: 101937.0000 - fp: 53.0000 - fn: 64.0000 - precision: 0.9817 - recall: 0.9780 - auc: 0.9963 - val_loss: 11.3532 - val_accuracy: 0.5861 - val_tp: 330.0000 - val_tn: 19504.0000 - val_fp: 201.0000 - val_fn: 233.0000 - val_precision: 0.6215 - val_recall: 0.5861 - val_auc: 0.7912
# Epoch 96/100
# 92/92 [==============================] - 43s 438ms/step - loss: 0.1015 - accuracy: 0.9822 - tp: 2858.0000 - tn: 101945.0000 - fp: 45.0000 - fn: 56.0000 - precision: 0.9845 - recall: 0.9808 - auc: 0.9968 - val_loss: 10.6478 - val_accuracy: 0.5808 - val_tp: 326.0000 - val_tn: 19494.0000 - val_fp: 211.0000 - val_fn: 237.0000 - val_precision: 0.6071 - val_recall: 0.5790 - val_auc: 0.8004
# Epoch 97/100
# 92/92 [==============================] - 43s 441ms/step - loss: 0.1895 - accuracy: 0.9787 - tp: 2849.0000 - tn: 101932.0000 - fp: 58.0000 - fn: 65.0000 - precision: 0.9800 - recall: 0.9777 - auc: 0.9956 - val_loss: 10.9429 - val_accuracy: 0.5897 - val_tp: 330.0000 - val_tn: 19509.0000 - val_fp: 196.0000 - val_fn: 233.0000 - val_precision: 0.6274 - val_recall: 0.5861 - val_auc: 0.8085
# Epoch 98/100
# 92/92 [==============================] - 43s 440ms/step - loss: 0.2116 - accuracy: 0.9753 - tp: 2830.0000 - tn: 101934.0000 - fp: 56.0000 - fn: 84.0000 - precision: 0.9806 - recall: 0.9712 - auc: 0.9957 - val_loss: 12.8762 - val_accuracy: 0.5755 - val_tp: 324.0000 - val_tn: 19491.0000 - val_fp: 214.0000 - val_fn: 239.0000 - val_precision: 0.6022 - val_recall: 0.5755 - val_auc: 0.7918
# Epoch 99/100
# 92/92 [==============================] - 43s 438ms/step - loss: 0.1731 - accuracy: 0.9794 - tp: 2852.0000 - tn: 101936.0000 - fp: 54.0000 - fn: 62.0000 - precision: 0.9814 - recall: 0.9787 - auc: 0.9970 - val_loss: 10.3090 - val_accuracy: 0.5826 - val_tp: 327.0000 - val_tn: 19509.0000 - val_fp: 196.0000 - val_fn: 236.0000 - val_precision: 0.6252 - val_recall: 0.5808 - val_auc: 0.7880
# Epoch 100/100
# 92/92 [==============================] - 43s 439ms/step - loss: 0.1119 - accuracy: 0.9798 - tp: 2851.0000 - tn: 101938.0000 - fp: 52.0000 - fn: 63.0000 - precision: 0.9821 - recall: 0.9784 - auc: 0.9975 - val_loss: 9.8380 - val_accuracy: 0.5790 - val_tp: 325.0000 - val_tn: 19505.0000 - val_fp: 200.0000 - val_fn: 238.0000 - val_precision: 0.6190 - val_recall: 0.5773 - val_auc: 0.8035

# %%
#save the model for reuse and comparing 
model_36.save('model_vegies_fruits')
# Out:
# INFO:tensorflow:Assets written to: model_vegies_fruits/assets

# %%
# evaluate the model 
model_36.evaluate(test_df_36)

#make predictions 
predictions_36 = model_36.predict(test_df_36)
# Out:
# 18/18 [==============================] - 59s 2s/step - loss: 7.9008 - accuracy: 0.6007 - tp: 341.0000 - tn: 19793.0000 - fp: 192.0000 - fn: 230.0000 - precision: 0.6398 - recall: 0.5972 - auc: 0.8175

# %% [markdown]
# # Part 2 : Model 1&2 performance metrics and evaluation

# %% [markdown]
# ## Loading the model history and model save file

# %%
# Loading the models into memory from the files 
model_148 = keras.models.load_model('model148')
model_36 = keras.models.load_model('../Jay-branch/model_veg_fruits')

# Loading the history files from history saved files
history_148 = pkl.load(open('model_148_history' , 'rb'))
history_36 = pkl.load(open('model_36_history' , 'rb'))

# %%
history_148.keys(), history_36.keys()
# Out:
# (dict_keys(['loss', 'accuracy', 'tp', 'tn', 'fp', 'fn', 'precision', 'recall', 'auc', 'val_loss', 'val_accuracy', 'val_tp', 'val_tn', 'val_fp', 'val_fn', 'val_precision', 'val_recall', 'val_auc']),
#  dict_keys(['loss', 'accuracy', 'tp', 'tn', 'fp', 'fn', 'precision', 'recall', 'auc', 'val_loss', 'val_accuracy', 'val_tp', 'val_tn', 'val_fp', 'val_fn', 'val_precision', 'val_recall', 'val_auc']))

# %% [markdown]
# ## Accuracy and Loss Per Epoch

# %%
# Creating the Accuracy and Loss figures 
fig_acc , (ax1 , ax2) = plt.subplots(2,1)
fig_loss , (ax3,ax4) = plt.subplots(2,1)

# adding title descriptions 
fig_acc.suptitle('Acccuracy for model 148 and model 36')
fig_loss.suptitle('Loss for model 148 and model 36')

# Plotting Accuracy for the model and the valdiation data for both models
ax1.plot(history_148['accuracy'])
ax1.plot(history_148['val_accuracy'])
ax1.legend(['train', 'test'], loc='upper left')
ax2.plot(history_36['accuracy'])
ax2.plot(history_36['val_accuracy'])
ax2.legend(['train', 'test'], loc='upper left')
# Plotting Loss for the model and the valdiation data for both models
ax3.plot(history_148['loss'])
ax3.plot(history_148['val_loss'])
ax3.legend(['train', 'test'], loc='upper left')
ax4.plot(history_36['loss'])
ax4.plot(history_36['val_loss'])
ax3.legend(['train', 'test'], loc='upper left')

# %% [markdown]
# ## Confusion Matrix and Classification Reports

# %%
# From Sklearn resources this is a function to plot the confusion matrix 
def plot_confusion_matrix(cm, classes,
                        normalize=False,
                        title='Confusion matrix',
                        cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(15,15))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Classification Report for the 148 Class Model
# although the model traning was done using the Image_dataset_from_directory method , it was much easier to obtain the needed structures using the ImageDataGenerator method 
test_generator_148 = ImageDataGenerator()
test_data_generator_148 = test_generator_148.flow_from_directory(
    '../Jay-branch/food_data/output/test', 
     target_size=(100, 100),
    batch_size=32,
    shuffle=False)
test_steps_per_epoch_148 = np.math.ceil(test_data_generator_148.samples / test_data_generator_148.batch_size)

# running the model predictions on the dataset genrated from ImageDataGenrator 
predictions_148 = model_148.predict(test_data_generator_148, steps=test_steps_per_epoch_148)

# refine the datastructure to only include the heights probability class 
predicted_classes_148 = np.argmax(predictions_148, axis=1)

# crate a list of the labels from the geenrated dataset
true_classes_148 = test_data_generator_148.classes
class_labels_148 = list(test_data_generator_148.class_indices.keys()) 

# Run the sklearn reporting method 
report_148 = classification_report(true_classes_148, predicted_classes_148, target_names=class_labels_148)
print(report_148)
# Out:
# Found 11415 images belonging to 148 classes.
#                          precision    recall  f1-score   support
#
#                   Bread       0.00      0.00      0.00       100
#           Dairy product       0.03      0.05      0.03        44
#                 Dessert       0.03      0.03      0.03       150
#                     Egg       0.00      0.00      0.00       100
#              Fried food       0.00      0.00      0.00        86
#                    Meat       0.00      0.00      0.00       133
#           Noodles-Pasta       0.00      0.00      0.00        44
#                    Rice       0.00      0.00      0.00        28
#                 Seafood       0.00      0.00      0.00        86
#                    Soup       0.32      0.25      0.28       150
#         Vegetable-Fruit       0.02      0.01      0.02        72
#                   apple       0.00      0.00      0.00         5
#               apple_pie       0.03      0.03      0.03       100
#          baby_back_ribs       0.13      0.03      0.05       100
#                 baklava       0.00      0.00      0.00       100
#                  banana       0.00      0.00      0.00         6
#          beef_carpaccio       0.03      0.01      0.02       100
#            beef_tartare       0.04      0.10      0.06       100
#              beet_salad       0.00      0.00      0.00       100
#                beetroot       0.00      0.00      0.00         8
#                beignets       0.01      0.01      0.01       100
#             bell pepper       0.00      0.00      0.00         9
#                bibimbap       0.00      0.00      0.00       100
#           bread_pudding       0.08      0.04      0.05       100
#       breakfast_burrito       0.02      0.03      0.02       100
#              bruschetta       0.01      0.01      0.01       100
#                 cabbage       0.33      0.10      0.15        10
#            caesar_salad       0.00      0.00      0.00       100
#                 cannoli       0.01      0.01      0.01       100
#           caprese_salad       0.06      0.08      0.07       100
#                capsicum       0.00      0.00      0.00        10
#                  carrot       0.00      0.00      0.00         9
#             carrot_cake       0.02      0.05      0.02       100
#             cauliflower       0.00      0.00      0.00         9
#                 ceviche       0.00      0.00      0.00       100
#            cheese_plate       0.01      0.03      0.01       100
#              cheesecake       0.00      0.00      0.00       100
#           chicken_curry       0.00      0.00      0.00       100
#      chicken_quesadilla       0.05      0.13      0.07       100
#           chicken_wings       0.03      0.03      0.03       100
#           chilli pepper       0.00      0.00      0.00        10
#          chocolate_cake       0.20      0.04      0.07       100
#        chocolate_mousse       0.00      0.00      0.00       100
#                 churros       0.04      0.01      0.02       100
#            clam_chowder       0.05      0.02      0.03       100
#           club_sandwich       0.00      0.00      0.00       100
#                    corn       0.00      0.00      0.00        10
#              crab_cakes       0.01      0.10      0.02       100
#            creme_brulee       0.00      0.00      0.00       100
#           croque_madame       0.13      0.08      0.10       100
#                cucumber       0.00      0.00      0.00         9
#               cup_cakes       0.08      0.02      0.03       100
#            deviled_eggs       0.06      0.04      0.05       100
#                  donuts       0.03      0.02      0.02       100
#               dumplings       0.14      0.03      0.05       100
#                 edamame       0.00      0.00      0.00       100
#                eggplant       0.00      0.00      0.00         8
#           eggs_benedict       0.00      0.00      0.00       100
#               escargots       0.02      0.01      0.01       100
#                 falafel       0.00      0.01      0.01       100
#            filet_mignon       0.00      0.00      0.00       100
#          fish_and_chips       0.06      0.01      0.02       100
#               foie_gras       0.00      0.00      0.00       100
#            french_fries       0.14      0.06      0.08       100
#       french_onion_soup       0.02      0.02      0.02       100
#            french_toast       0.04      0.04      0.04       100
#          fried_calamari       0.08      0.02      0.03       100
#              fried_rice       0.13      0.16      0.14       100
#           frozen_yogurt       0.01      0.02      0.02       100
#                  garlic       0.00      0.00      0.00        10
#            garlic_bread       0.00      0.00      0.00       100
#                  ginger       0.00      0.00      0.00         7
#                 gnocchi       0.00      0.00      0.00       100
#                  grapes       0.00      0.00      0.00        10
#             greek_salad       0.03      0.06      0.04       100
# grilled_cheese_sandwich       0.01      0.01      0.01       100
#          grilled_salmon       0.00      0.00      0.00       100
#               guacamole       0.00      0.00      0.00       100
#                   gyoza       0.08      0.01      0.02       100
#               hamburger       0.02      0.02      0.02       100
#       hot_and_sour_soup       0.00      0.00      0.00       100
#                 hot_dog       0.02      0.08      0.04       100
#        huevos_rancheros       0.01      0.01      0.01       100
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# output the confusion matrix 
cm_148 = confusion_matrix(y_true=test_data_generator_148.classes, y_pred=predicted_classes_148)
    
# plot the CM using the defined method from SKlearn 
plot_confusion_matrix(cm=cm_148 , classes= class_labels_148 , title='Confusion Matrix 148 Classes')
# Out:
# Confusion matrix, without normalization
# [[0 0 0 ... 0 0 0]
#  [0 2 0 ... 0 0 0]
#  [0 0 4 ... 0 4 0]
#  ...
#  [0 0 0 ... 0 0 0]
#  [0 0 7 ... 0 4 0]
#  [0 0 0 ... 0 0 0]]

# %%
# Classification Report for the 36 Class Model using the above method
test_generator_36 = ImageDataGenerator()
test_data_generator_36 = test_generator_36.flow_from_directory(
    'veg_fruits/validation', 
     target_size=(100, 100),
    batch_size=32,
    shuffle=False)
test_steps_per_epoch_36 = np.math.ceil(test_data_generator_36.samples / test_data_generator_36.batch_size)

predictions_36 = model_36.predict(test_data_generator_36, steps=test_steps_per_epoch_36)

predicted_classes_36 = np.argmax(predictions_36, axis=1)

true_classes_36 = test_data_generator_36.classes
class_labels_36 = list(test_data_generator_36.class_indices.keys()) 

report_36 = classification_report(true_classes_36, predicted_classes_36, target_names=class_labels_36)
print(report_36)
# Out:
# Found 563 images belonging to 36 classes.
#                precision    recall  f1-score   support
#
#         apple       0.44      0.70      0.54        10
#        banana       0.58      0.78      0.67         9
#      beetroot       0.67      1.00      0.80        10
#   bell pepper       0.75      1.00      0.86         9
#       cabbage       0.71      1.00      0.83        10
#      capsicum       0.75      0.90      0.82        10
#        carrot       0.62      1.00      0.76         8
#   cauliflower       0.43      1.00      0.61        10
# chilli pepper       0.39      1.00      0.56         7
#          corn       0.46      0.60      0.52        10
#      cucumber       0.45      1.00      0.62        10
#      eggplant       0.62      1.00      0.77        10
#        garlic       0.83      1.00      0.91        10
#        ginger       0.83      1.00      0.91        10
#        grapes       0.60      1.00      0.75         9
#      jalepeno       0.41      1.00      0.58         9
#          kiwi       0.71      1.00      0.83        10
#         lemon       0.58      1.00      0.74         7
#       lettuce       0.47      1.00      0.64         9
#         mango       0.59      1.00      0.74        10
#         onion       0.90      1.00      0.95         9
#        orange       1.00      0.06      0.11       230
#       paprika       0.59      1.00      0.74        10
#          pear       0.31      1.00      0.48        10
#          peas       0.60      1.00      0.75         9
#     pineapple       0.71      1.00      0.83        10
#   pomegranate       0.77      1.00      0.87        10
#        potato       1.00      0.80      0.89        10
#       raddish       0.62      1.00      0.76         8
#     soy beans       0.69      0.90      0.78        10
#       spinach       0.45      1.00      0.62        10
#     sweetcorn       0.42      1.00      0.59        10
#   sweetpotato       0.80      0.80      0.80        10
#        tomato       0.59      1.00      0.74        10
#        turnip       0.64      0.90      0.75        10
#    watermelon       0.53      1.00      0.69        10
#
#      accuracy                           0.59       563
#     macro avg       0.63      0.93      0.72       563
#  weighted avg       0.77      0.59      0.48       563

# %%
# output the confusion matrix 
cm_36 = confusion_matrix(y_true=test_data_generator_36.classes, y_pred=predicted_classes_36)
    
# plot the CM using the defined method from SKlearn 
plot_confusion_matrix(cm=cm_36 , classes= class_labels_36 , title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[ 7  0  0 ...  0  0  0]
#  [ 0  7  0 ...  0  0  0]
#  [ 0  0 10 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 10  0  0]
#  [ 0  0  0 ...  0  9  0]
#  [ 0  0  0 ...  0  0 10]]
