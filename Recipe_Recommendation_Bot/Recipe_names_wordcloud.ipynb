# %%
# Program to generate Recipe Word Cloud

# import all necessary modules
from PIL import Image
import numpy as np
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib as mpl

# %%
# Read CSV File
import os
df = pd.read_csv("recipe_names.csv", on_bad_lines="skip")

text = " ".join(df["roast-duck-with-marsala-gravy"])

text
# Out:
# "best-ever-brussels-sprouts beautiful-courgette-penne-carbonara roasted-black-bean-burgers chicken-tofu-noodle-soup chicken-katsu-curry roasted-salmon-artichokes cracker-ravioli black-bean-burgers panish-tortilla tomato-red-wine-chorizo-risotto venison-shanks-juniper-amp-redcurrants roasted-brassicas-with-puy-lentils-halloumi quick-fish-cakes asian-salmon-sweet-potato-traybake sliced-fennel-orange-almond-salad roasted-squash-couscous-salad chicken-in-a-pot mash-topped-beef-guinness-pie wild-rice-salad thai-style-mussels chicken-milanese-with-spaghetti tomato-caper-linguine black-blushing-worcestershire-fillet spring-chicken-pie lamb-chickpea-curry minestrone-soup roast-chicken-with-potatoes-carrots salmon-pesto-dressed-veg veggie-noodle-stir-fry simple-cheese-omelette bean-curd-with-lau-s-spicy-ma-po-sauce christmas-carbonara chicken-broth-with-tortellini griddled-vegetables-feta-with-tabbouleh chicken-wings-agrodolce-style southern-italian-style-chicken sweet-sour-chicken roasted-ro
# ...

# %%
# read the mask/color image taken from
#coloring = np.array(Image.open('.jpg'))
stopwords = set(STOPWORDS)
custom_stop_words = [""]
[stopwords.add(n) for n in custom_stop_words]
# Out:
# [None]

# %%
wc = WordCloud(background_color="white" , width=500, max_words=200, 
              stopwords=stopwords, max_font_size=100, random_state=42)

#generate word cloud
wc.generate(text)
fontdict={"fontsize": 32, "fontweight":"bold"}
plt.title("Recipe Word Cloud", fontdict=fontdict)
plt.imshow(wc)
